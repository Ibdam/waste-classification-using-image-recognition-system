# %%
"""
The model is too high for deployemnt, then convertion to smaller size has to be taken place
    
"""

import tensorflow as tf

# Load your trained Keras model
model = tf.keras.models.load_model("waste_model.h5")

# Convert to TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model
with open("converted_waste_model.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Conversion complete! Model saved as waste_model.tflite")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\ADMIN\AppData\Local\Temp\tmph6sty6z3\assets
# INFO:tensorflow:Assets written to: C:\Users\ADMIN\AppData\Local\Temp\tmph6sty6z3\assets
# Saved artifact at 'C:\Users\ADMIN\AppData\Local\Temp\tmph6sty6z3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   3068087401744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3068087400784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3068087401360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3068087400208: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
